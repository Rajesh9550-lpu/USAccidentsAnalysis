# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("US_Accidents_Dec21_updated.csv")
data.head()
# Out:
#     ID  Severity        Start_Time          End_Time  Start_Lat  Start_Lng  \
# 0  A-1         3  08-02-2016 00:37  08-02-2016 06:37  40.108910 -83.092860
# 1  A-2         2  08-02-2016 05:56  08-02-2016 11:56  39.865420 -84.062800
# 2  A-3         2  08-02-2016 06:15  08-02-2016 12:15  39.102660 -84.524680
# 3  A-4         2  08-02-2016 06:51  08-02-2016 12:51  41.062130 -81.537840
# 4  A-5         3  08-02-2016 07:53  08-02-2016 13:53  39.172393 -84.492792
#
#      End_Lat    End_Lng  Distance  \
# 0  40.112060 -83.031870     3.230
# 1  39.865010 -84.048730     0.747
# 2  39.102090 -84.523960     0.055
# 3  41.062170 -81.535470     0.123
# 4  39.170476 -84.501798     0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
data.isnull().sum()
# Out:
# ID                            0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                       0
# End_Lng                       0
# Distance                      0
# Description                   0
# Number                   615177
# Street                        1
# Side                          0
# City                         55
# County                        0
# State                         0
# Zipcode                     435
# Country                       0
# Timezone                   1026
# Airport_Code               3647
# Weather_Timestamp         15516
# Unnamed: 21               21746
# Wind_Chill(F)            214122
# Unnamed: 23               22728
# Pressure(in)              18585
# Visibility(mi)            22534
# Wind_Direction            22626
# Wind_Speed(mph)           57687
# Precipitation(in)        231683
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1048575 non-null  object
#  1   Severity               1048575 non-null  int64
#  2   Start_Time             1048575 non-null  object
#  3   End_Time               1048575 non-null  object
#  4   Start_Lat              1048575 non-null  float64
#  5   Start_Lng              1048575 non-null  float64
#  6   End_Lat                1048575 non-null  float64
#  7   End_Lng                1048575 non-null  float64
#  8   Distance               1048575 non-null  float64
#  9   Description            1048575 non-null  object
#  10  Number                 433398 non-null   float64
#  11  Street                 1048574 non-null  object
#  12  Side                   1048575 non-null  object
# ...

# %%
Distance_mean=data.Distance.mean()
Distance_mean
# Out:
# 0.8056515356555425

# %%
data.Distance.fillna(Distance_mean,inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                            0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                       0
# End_Lng                       0
# Distance                      0
# Description                   0
# Number                   615177
# Street                        1
# Side                          0
# City                         55
# County                        0
# State                         0
# Zipcode                     435
# Country                       0
# Timezone                   1026
# Airport_Code               3647
# Weather_Timestamp         15516
# Unnamed: 21               21746
# Wind_Chill(F)            214122
# Unnamed: 23               22728
# Pressure(in)              18585
# Visibility(mi)            22534
# Wind_Direction            22626
# Wind_Speed(mph)           57687
# Precipitation(in)        231683
# ...

# %%
sns.boxplot(data.End_Lng )
plt.show()
# Out:
# C:\Users\hgjygj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#IQR
Q1=np.percentile(data.Distance,25,interpolation='midpoint')
Q3=np.percentile(data.Distance,75,interpolation='midpoint')
IQR=Q3-Q1
print("Q1==",Q1)
print("Q3==",Q3)
print("IQR==",IQR)
# Out:
# Q1== 0.107
# Q3== 0.89
# IQR== 0.783

# %%
#HISTOPLOT
sns.histplot(data.Nautical_Twilight)
plt.show()
histplot

# %%
sns.rugplot(data.Distance)
plt.show()

# %%
sns.violinplot(data.Distance)
# Out:
# C:\Users\hgjygj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Distance'>

# %%
sns.stripplot(data.Distance)
# Out:
# C:\Users\hgjygj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Distance'>

# %%
# Scatter Plot
data.plot.scatter(x="Distance",y="Visibility(mi)")
plt.show()

# %%
# Correlation Matrix
sns.heatmap(data[["Distance","Number"]].corr(), annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
data.mode()
# Out:
#                ID  Severity Start_Time End_Time  Start_Lat  Start_Lng  \
# 0             A-1       2.0    23:00.0  45:00.0  28.452192 -81.400388
# 1            A-10       NaN        NaN      NaN        NaN        NaN
# 2           A-100       NaN        NaN      NaN        NaN        NaN
# 3          A-1000       NaN        NaN      NaN        NaN        NaN
# 4         A-10000       NaN        NaN      NaN        NaN        NaN
# ...           ...       ...        ...      ...        ...        ...
# 1048570  A-999995       NaN        NaN      NaN        NaN        NaN
# 1048571  A-999996       NaN        NaN      NaN        NaN        NaN
# 1048572  A-999997       NaN        NaN      NaN        NaN        NaN
# 1048573  A-999998       NaN        NaN      NaN        NaN        NaN
# 1048574  A-999999       NaN        NaN      NaN        NaN        NaN
#
#            End_Lat    End_Lng  Distance  \
# 0        25.701774 -80.334179       0.0
# 1              NaN        NaN       NaN
# ...

# %%
data.std()
# Out:
# C:\Users\hgjygj\AppData\Local\Temp/ipykernel_30256/2723740006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# Severity                 0.431510
# Start_Lat                5.388367
# Start_Lng               17.857320
# End_Lat                  5.388549
# End_Lng                 17.857116
# Distance                 1.525762
# Number               14450.352867
# Unnamed: 21             17.354721
# Wind_Chill(F)           19.730705
# Unnamed: 23             22.492491
# Pressure(in)             0.992776
# Visibility(mi)           2.563857
# Wind_Speed(mph)          5.422827
# Precipitation(in)        0.109322
# Amenity                  0.101990
# Bump                     0.019601
# Crossing                 0.252930
# Give_Way                 0.047628
# Junction                 0.295142
# ...

# %%
data.var()
# Out:
# C:\Users\hgjygj\AppData\Local\Temp/ipykernel_30256/445316826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# Severity             1.862009e-01
# Start_Lat            2.903450e+01
# Start_Lng            3.188839e+02
# End_Lat              2.903646e+01
# End_Lng              3.188766e+02
# Distance             2.327950e+00
# Number               2.088127e+08
# Unnamed: 21          3.011863e+02
# Wind_Chill(F)        3.893007e+02
# Unnamed: 23          5.059122e+02
# Pressure(in)         9.856049e-01
# Visibility(mi)       6.573362e+00
# Wind_Speed(mph)      2.940706e+01
# Precipitation(in)    1.195131e-02
# Amenity              1.040186e-02
# Bump                 3.841838e-04
# Crossing             6.397371e-02
# Give_Way             2.268395e-03
# Junction             8.710895e-02
# ...

# %%
# Correlation
corr = data.corr()
corr
# Out:
#                    Severity  Start_Lat  Start_Lng   End_Lat   End_Lng  \
# Severity           1.000000   0.096283   0.086884  0.096278  0.086885
# Start_Lat          0.096283   1.000000  -0.133671  0.999995 -0.133666
# Start_Lng          0.086884  -0.133671   1.000000 -0.133666  0.999999
# End_Lat            0.096278   0.999995  -0.133666  1.000000 -0.133662
# End_Lng            0.086885  -0.133666   0.999999 -0.133662  1.000000
# Distance           0.071241   0.105062  -0.012683  0.105053 -0.012696
# Number            -0.002827   0.059929  -0.155316  0.059940 -0.155320
# Unnamed: 21       -0.065010  -0.459609   0.064378 -0.459600  0.064379
# Wind_Chill(F)     -0.139732  -0.498062   0.057078 -0.498053  0.057078
# Unnamed: 23        0.030138  -0.035614   0.159204 -0.035621  0.159197
# Pressure(in)       0.072971  -0.259296   0.233887 -0.259304  0.233884
# Visibility(mi)     0.008115  -0.078882   0.061807 -0.078877  0.061809
# ...

# %%
plt.subplots(figsize=(29,8))
corr = data.corr()
sns.heatmap(corr,annot=True,
           xticklabels = corr.columns.values,
           yticklabels = corr.columns.values);
plt.show()

# %%
data.skew()
# Out:
# C:\Users\hgjygj\AppData\Local\Temp/ipykernel_30256/1188251951.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# Severity               3.664003
# Start_Lat             -0.086606
# Start_Lng             -0.427922
# End_Lat               -0.086588
# End_Lng               -0.427929
# Distance              12.896420
# Number                20.425126
# Unnamed: 21           -0.596524
# Wind_Chill(F)         -0.837965
# Unnamed: 23           -0.352040
# Pressure(in)          -3.534548
# Visibility(mi)         2.980849
# Wind_Speed(mph)       11.675400
# Precipitation(in)     81.103616
# Amenity                9.598801
# Bump                  50.979711
# Crossing               3.410494
# Give_Way              20.900766
# Junction               2.734942
# No_Exit               25.141966
# ...

# %%
# 2. PIE CHART
df = data['Stop'].value_counts()
plt.pie(df, labels=df.index, autopct="%.0f%%");

# %%
sns.pairplot(data,hue="Distance",size=3)
